# %% [markdown]
# # webscraping assignment 4

# %% [markdown]
# Q)NO:7,RECRUITERS FROM NAUKRI

# %%
import selenium

# %%
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd

# %%
from selenium import webdriver

# %%
from selenium.webdriver.chrome.options import Options

# %%
PATH = r"/Users/akshathaaravind/Downloads/chromedriver"

# %%
driver=webdriver.Chrome(PATH)
# Out:
# <ipython-input-8-39becb130489>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(PATH)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
driver.get("https://www.naukri.com/")

# %%
RECRUITER_TAB=driver.find_element_by_xpath("//span[@class='topIcon jobs Recr']/div")
RECRUITER_TAB.CLICK()

# %%
SEARCH_TAB=driver.find_elements_by_xpath("//div[@class='sWrap lftBrd sHide']/span")
SEARCH_TAB.send_keys("Data Science")

# %%
search_button=driver.find_elements_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search_button.click()

# %%
NAME=[]
DESIGNATION=[]
COMPANY=[]
SKILL=[]
LOCATION=[]

# %%
name_tag=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")

# %%
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="4c8f6b00-02cb-4c15-b3d0-17c096c0b605")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="c4b19fab-0c0d-4838-a83f-bb6aa474712e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="3dddff48-50b6-4d00-aa62-2ebd38943835")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="0064faea-b857-451b-af93-df53dfc81e83")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="fde73330-0dcd-45f8-9321-9dc96cec0588")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="a14267cb-01d1-4081-952b-638f767651d9")>,
# ...

# %%
for i in name_tag:
    title=i.text
    NAME.append(title)

# %%
NAME
# Out:
# ['Aakash Harit',
#  'shravan Kumar Gaddam',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'subhas patel',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Institute for Financial Management and Resear',
#  'Balu Ramesh',
#  'Asif Lucknowi',
#  'InstaFinancials',
#  'Priyanka Akiri',
#  'Kalpana Dumpala',
#  'Mubarak',
#  'Kushal Rastogi',
#  'Mahesh Babu Channa',
#  'Sakshi Chhikara',
#  'Kapil Devang',
#  'Ruchi Dhote',
#  'Sandhya Khandagale',
#  'Manisha Yadav',
#  'Riya Rajesh',
#  'Rashmi Bhattacharjee',
#  'Faizan Kareem',
#  'Rithika dadwal',
#  'Shaun Rao',
#  'Azahar Shaikh',
#  'Manas',
#  'kumar',
#  'Sunil Vedula',
#  'Rajat Kumar',
#  'Avodha',
#  'Jayanth N',
#  'Priya Khare',
#  'Dhruv Dev Dubey',
#  'Prateek Kumar',
#  'Amit Sharma',
#  'Kanan',
#  'Shashikant Chaudhary',
#  'Brad',
#  'Rutuja Pawar',
#  'Madhusudhan Sridhar',
#  'Ankit Sinha',
#  'Gaurav Chouhan',
#  'Rashi Kacker',
#  'Ashwini',
#  'Balaji Kolli',
#  'Rajani Nagaraj',
#  'ROHIT Kumar',
# ...

# %%
designation_tag=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")

# %%
designation_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="b6afd0a3-59ba-4f5f-86bd-7f7829473079")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="b644f320-dc15-44e6-aa62-a704652aed32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="a7ad66b2-9538-4c1d-bb02-b11e3d86b643")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="518d484e-90bc-4e47-ae99-83759a08848d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="a3c6d453-1a92-43e8-aa45-1a8f66c30b0a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="be55fcd6-5e81-4346-a462-4f68c9aa1f7c")>,
# ...

# %%
for i in designation_tag:
    dtitle=i.text
    DESIGNATION.append(dtitle)

# %%
DESIGNATION
# Out:
# ['HR Manager',
#  'Company Recruiter',
#  'Company HR',
#  'Company Recruiter',
#  'Founder CEO',
#  'Recruitment Lead Consultant',
#  'Programme Manager',
#  'HR Administrator',
#  'Director',
#  'Human Resource',
#  'HR Manager',
#  'Executive Hiring',
#  'Company HR',
#  'Company HR',
#  'HR Team Lead',
#  'Assistant Manager HR',
#  'HR Manager',
#  'Senior Executive Talent Acquisition',
#  'HR Recruiter',
#  'HR Executive',
#  'Manager Talent Acquisition',
#  'HR Head',
#  'HR MANAGER',
#  'HR Recruiter',
#  'Manager Human Resources',
#  'Company Recruiter',
#  'Lead Talent acquisition',
#  'Proprietor',
#  'CEO',
#  'Founder CEO',
#  'Business Development Associate',
#  'Project Manager',
#  'Senior Manager',
#  'Company Recruitment Head',
#  'Head',
#  'Consultant',
#  'senior technology instructor',
#  'HR Recruiter/HR Excutive',
#  'Manager, Technical Recruiting',
#  'Technical Recruiter',
#  'Erp Implementer',
#  'Head Analytics',
#  'Chief Technical Officer',
# ...

# %%
company_tag=driver.find_elements_by_xpath("//i[@class='cmpIcn']")

# %%
company_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="cb090852-2f92-4468-b2ab-f059e64d84a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="55ef26ac-2fd1-46ce-9806-59c984165a94")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="62522a9e-cfd9-460c-b8b6-f90af05ace07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="0efe78c1-c285-4421-8e5f-7b8b40faf73e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="b4608575-e726-41db-892a-3398436e103c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="dc461ed2-4878-4d73-ba11-38cd5b7d34c5")>,
# ...

# %%
for i in company_tag:
    ctitle=i.text
    COMPANY.append(ctitle)

# %%
location_tag=driver.find_elements_by_xpath("//small[@class='ellipsis']")

# %%
location_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="604fa446-c572-4cc6-b465-f957d17767bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="45feb8e2-8732-4a31-81a7-e5fd43b34e38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="f66427d7-fbf7-4b4d-b7c6-ffe7973d38f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="37c57bb5-c934-4c35-a63a-cf01c4e188ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="134d7677-a4ed-49f6-af6d-d0a389ba3334")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="da636388-8648-43bd-9a8f-6105d07b4057")>,
# ...

# %%
for i in location_tag:
    lotitle=i.text
    LOCATION.append(lotitle)

# %%
LOCATION
# Out:
# ['Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Ahmedabad',
#  'UK - (london)',
#  'Vadodara / Baroda',
#  'Chennai',
#  'Trivandrum',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'Hyderabad',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Hyderabad / Secunderabad',
#  'Chandigarh',
#  'Bhopal',
#  'Pune',
#  'Pune',
#  'Navi Mumbai',
#  'Cochin',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Mysoru / Mysore',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Noida',
#  'New Delhi',
#  'Chennai',
#  'Aligarh',
#  'Salt Lake City',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'MYSORE',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Hyderabad / Secunderabad']

# %%
skill_tag=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")

# %%
skill_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="2b39a2fb-d40a-4195-ac77-37fb56e7b0ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="2f43e426-34fa-4cbf-b12e-363bdea0fee7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="4e0edcbd-72a0-4bcd-bd66-f7f3ce3602b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="df77e4ba-5de3-4ff5-bbfe-43836dbf9b11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="a21f8dc7-7515-423c-919b-228977cfaeba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5b6eca404064d217f7dc2d803bb48fb6", element="a3c8d7b8-9155-4d31-81b9-cb1ad483ba8e")>,
# ...

# %%
for i in skill_tag:
    sktitle=i.text
    SKILL.append(sktitle)

# %%
SKILL
# Out:
# ['Classic ASP Developer, Internet Marketing Professional, Data Science SME, Content Writers, SEO Professional, Revenue Professional',
#  '.Net, Java, Data Science, Linux Administration, Sql Server Development, Winforms, Wcf Services, Wpf, Telecom Engineering, Technical Management, Software',
#  'Data Science, Artificial Intelligence, Machine Learning, Business Analytics',
#  'Mean Stack, javascript, angularjs, mongodb, Web Services, rest, express, Node.js, Big Data, iot, Data Science, Cloud Computing, saas, Aws',
#  'Hadoop, Spark, Digital Strategy, Data Architecture, Command Center, Cdp, Dmp, Kafka, Data Science, Data Analysis, Big Data Analytics, Real Time Analysis, SQL',
#  'Analytics, Business Intelligence, Business Analytics, Predictive Modeling, Predictive Analytics, Data Science, Data Analysis, Data Analytics, Big Data, Big',
#  'Data Science',
# ...

# %%
len(NAME)
# Out:
# 50

# %%
len(DESIGNATION)
# Out:
# 50

# %%
len(LOCATION)
# Out:
# 48

# %%
len(SKILL)
# Out:
# 50

# %%
Recruiters=pd.DataFrame({})

# %%
Recruiters['Name']=NAME
Recruiters['Position']=DESIGNATION
Recruiters['Skill']=SKILL

# %%
Recruiters
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %% [markdown]
# # Q)9)BEST TV SERIES FROM IMBD

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
Name=[]

# %%
name_tag=driver.find_elements_by_xpath("//h3[@class='lister-item-header']")

# %%
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="2ed4fca3-0e43-4f8a-8c95-6e1e7a70fbea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="b49e01b2-678a-4bbd-af07-f5fc551b13a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="b6627dc3-8120-4459-99a3-935e13a187f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="6db6e7fd-52a1-4916-bb17-ac85f37f93cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="3866f69c-e7ed-4e57-8add-682181d6ddb3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="0fa499d0-a190-4fca-8fa8-5e3f0383a05d")>,
# ...

# %%
for i in name_tag:
    nametitle=i.text
    Name.append(nametitle)

# %%
 Name
# Out:
# ['1. Game of Thrones (2011–2019)',
#  '2. Stranger Things (2016– )',
#  '3. The Walking Dead (2010–2022)',
#  '4. 13 Reasons Why (2017–2020)',
#  '5. The 100 (2014–2020)',
#  '6. Orange Is the New Black (2013–2019)',
#  '7. Riverdale (2017– )',
#  "8. Grey's Anatomy (2005– )",
#  '9. The Flash (2014– )',
#  '10. Arrow (2012–2020)',
#  '11. Money Heist (2017–2021)',
#  '12. The Big Bang Theory (2007–2019)',
#  '13. Black Mirror (2011–2019)',
#  '14. Sherlock (2010–2017)',
#  '15. Vikings (2013–2020)',
#  '16. Pretty Little Liars (2010–2017)',
#  '17. The Vampire Diaries (2009–2017)',
#  '18. American Horror Story (2011– )',
#  '19. Breaking Bad (2008–2013)',
#  '20. Lucifer (2016–2021)',
#  '21. Supernatural (2005–2020)',
#  '22. Prison Break (2005–2017)',
#  '23. How to Get Away with Murder (2014–2020)',
#  '24. Teen Wolf (2011–2017)',
#  '25. The Simpsons (1989– )',
#  '26. Once Upon a Time (2011–2018)',
#  '27. Narcos (2015–2017)',
#  '28. Daredevil (2015–2018)',
# ...

# %%
Year=[]

# %%
year_tag=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")

# %%
year_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="def90195-7546-44e7-8fb4-1d0598e26c56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="b63389dc-3f26-4356-9261-f4d017cbd400")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="e84bfea7-70c5-493c-a8b4-27fc5b042ba3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="522fdf57-8c3a-4cb2-a5b2-f6083ec2520a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="2b4530d1-360b-4bf4-b785-2bf65ac642f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="9eed8101-dce5-4600-b972-b0ce8ca49614")>,
# ...

# %%
for i in year_tag:
    yeartitle=i.text
    Year.append(yeartitle)

# %%
Year
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011–2019)',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016– )',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2013)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013–2022)',
# ...

# %%
len(Year)
# Out:
# 100

# %%
Genre=[]

# %%
genre_tag=driver.find_elements_by_xpath("//span[@class='genre']")

# %%
genre_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="600423e1-fa28-46d1-9a41-f2e87eb5f612")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="d4d8b3c7-b0f6-4818-85b8-350ed43aa083")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="252db086-1a6f-48d0-acdc-a9d6da3afc32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="d8cd1ef0-9574-4fb6-b210-18285bcc7f58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="7e89bc72-7ba5-4f15-a3e3-2b35d5bb4c2a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="edf8d074-c5cf-4d78-86b9-a2fe8e716bd1")>,
# ...

# %%
for i in genre_tag:
    genretitle=i.text
    Genre.append(genretitle)

# %%
Genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Sci-Fi, Thriller',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %%
len(Genre)
# Out:
# 100

# %%
Time=[]

# %%
time_tag=driver.find_elements_by_xpath("//span[@class='runtime']")

# %%
time_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="8a88c670-e0de-4836-97b0-eeefb8d57a49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="e0ae7e9c-8a3b-498b-8b99-d6e75f368027")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="500d8851-7414-42a6-b15a-a80e6ae0f43c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="d3cfbb24-a4aa-4923-a53e-f2daad21c61b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="6e00b6f1-dac2-4078-a94f-d4cf7582e2de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="a935d88c-3048-4953-8ebb-2adea3ac2d8e")>,
# ...

# %%
for i in time_tag:
    timetitle=i.text
    Time.append(timetitle)

# %%
Time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
len(Time)
# Out:
# 100

# %%
Ratings=[]

# %%
rating_tag=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']")

# %%
rating_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="67950bf4-4958-4728-bd3b-60c92b7af127")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="249055fe-0778-44e0-866e-b5a6b47cdebb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="1bd97b0c-9e7a-400e-9ef0-c3bd96563da7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="605211de-5f23-42ca-8b6c-3f51bd184bd1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="f6e2af1b-4346-49b5-8db5-4611801867b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="05a6922a-f617-441d-aabe-9b5ba3535701")>,
# ...

# %%
for i in rating_tag:
    ratingtitle=i.text
    Ratings.append(ratingtitle)

# %%
Ratings
# Out:
# ['9.2',
#  '8.7',
#  '8.2',
#  '7.5',
#  '7.6',
#  '8',
#  '6.7',
#  '7.5',
#  '7.6',
#  '7.5',
#  '8.2',
#  '8.1',
#  '8.8',
#  '9.1',
#  '8.5',
#  '7.4',
#  '7.7',
#  '8',
#  '9.4',
#  '8.1',
#  '8.4',
#  '8.3',
#  '8.1',
#  '7.6',
#  '8.6',
#  '7.7',
#  '8.8',
#  '8.6',
#  '8.8',
#  '8.3',
#  '8.4',
#  '8.5',
#  '8.2',
#  '6.2',
#  '7.4',
#  '8.3',
#  '7.8',
#  '8.6',
#  '7.9',
#  '8.4',
#  '9.2',
#  '6.6',
#  '8.1',
#  '8.7',
#  '8.8',
#  '7.4',
#  '8.3',
#  '8.5',
#  '7.7',
#  '7.5',
#  '7.7',
#  '8.6',
#  '6.9',
#  '8.1',
#  '8',
#  '8.3',
#  '8.8',
#  '8.7',
#  '6.7',
#  '8.3',
#  '8.3',
#  '7.4',
#  '6.8',
#  '8.4',
#  '7.5',
#  '8.1',
#  '7.8',
#  '6.7',
#  '8.7',
#  '8.4',
#  '6.6',
#  '8',
#  '8.9',
#  '7.8',
#  '7.5',
#  '8.8',
#  '8.1',
#  '8.5',
#  '8.3',
#  '7.3',
#  '8.6',
#  '8.2',
#  '6.4',
#  '6.3',
#  '8.6',
#  '7.8',
#  '7.3',
#  '7.7',
#  '7.3',
#  '8.5',
#  '6.5',
#  '8.1',
#  '8.6',
#  '9.4',
#  '7.8',
#  '7.5',
#  '7.8',
#  '8.1',
#  '7.1',
#  '8.6']

# %%
len(Ratings)
# Out:
# 100

# %%
Best_Series=pd.DataFrame({})

# %%
Best_Series['NAME']=Name
Best_Series['YEAR']=Year
Best_Series['GENRE']=Genre
Best_Series['TIME']=Time
Best_Series['RATING']=Ratings

# %%
Best_Series
# Out:
#                                               NAME         YEAR  \
# 0                   1. Game of Thrones (2011–2019)  (2011–2019)
# 1                      2. Stranger Things (2016– )     (2016– )
# 2                  3. The Walking Dead (2010–2022)  (2010–2022)
# 3                    4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4                           5. The 100 (2014–2020)  (2014–2020)
# ..                                             ...          ...
# 95                           96. Reign (2013–2017)  (2013–2017)
# 96  97. A Series of Unfortunate Events (2017–2019)  (2017–2019)
# 97                  98. Criminal Minds (2005–2020)  (2005–2020)
# 98           99. Scream: The TV Series (2015–2019)  (2015–2019)
# 99          100. The Haunting of Hill House (2018)       (2018)
#
#                        GENRE     TIME RATING
# 0   Action, Adventure, Drama   57 min    9.2
# 1     Drama, Fantasy, Horror   51 min    8.7
# 2    Drama, Horror, Thriller   44 min    8.2
# ...

# %% [markdown]
# # Q)2)INTERNATIONAL FXTURES FROM BCCI

# %%
driver.get("https://www.bcci.tv/")

# %%
international_tag=driver.find_elements_by_xpath("//a[@class='nav-link']")

# %%
for i in international_tag:
    if i.text=='INTERNATIONAL':
        i.click()
        break

# %%
fixtures_tab=driver.find_elements_by_id("fixtures-tab")
fixtures_tab.click()

# %%
NAME=[]

# %%
name_tag=driver.find_elements_by_xpath("//div[@class='fixture-card-top']/h5[2]")

# %%
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="e285cad2-ceb6-47c9-a21a-e7a4d4d11897")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="a0266987-65fe-4be5-ae79-fdac225ac937")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="e8ef3d8b-04b0-47a7-b348-d48988831fcc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="8e4dcff2-aeec-487d-95bd-a837a9dd1a53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="7c0079b2-5422-4795-adc8-e217ebdfdfeb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="d2f7c838-55da-4245-965d-0f27389ed0e7")>,
# ...

# %%
for i in name_tag:
    ntitle=i.text
    NAME.append(ntitle)

# %%
NAME
# Out:
# ['INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22',
#  'ACC U19 - ASIA CUP 2021',
#  'INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22',
#  'INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22',
#  'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#  'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#  'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22']

# %%
PLACE=[]

# %%
place_tag=driver.find_elements_by_xpath("//div[@class='fixture-card-bottom']")

# %%
place_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="575625c1-8c63-419d-8de2-e47d64c674a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="2f285652-caaa-42d2-a784-596e56822d62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="c201eb88-db20-4e9d-a559-5fc32d5de584")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="542cad6a-778a-4788-a600-fd7e396f7bc4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="ac570af7-7e5c-49be-a4ca-e2da36cd2414")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="e0573fa6-daf4-4cb2-9be9-b8a210169f7e")>,
# ...

# %%
for i in place_tag:
    ptitle=i.text.split("-")[1]
    PLACE.append(ptitle)

# %%
PLACE
# Out:
# [' SuperSport Park, Centurion\nMatch Centre',
#  ' ICC Academy ',
#  ' The Wanderers Stadium, Johannesburg\nMatch Centre',
#  ' Newlands, Cape Town\nMatch Centre',
#  ' Boland Park, Paarl\nMatch Centre',
#  ' Boland Park, Paarl\nMatch Centre',
#  ' Newlands, Cape Town\nMatch Centre']

# %%
TITLE=[]

# %%
title_tag=driver.find_elements_by_xpath("//div[@class='fixture-card-bottom']")

# %%
title_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="575625c1-8c63-419d-8de2-e47d64c674a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="2f285652-caaa-42d2-a784-596e56822d62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="c201eb88-db20-4e9d-a559-5fc32d5de584")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="542cad6a-778a-4788-a600-fd7e396f7bc4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="ac570af7-7e5c-49be-a4ca-e2da36cd2414")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="e0573fa6-daf4-4cb2-9be9-b8a210169f7e")>,
# ...

# %%
for i in title_tag:
    ttitle=i.text.split("-")[0]
    TITLE.append(ttitle)

# %%
TITLE
# Out:
# ['1st Test ',
#  '9th ODI ',
#  '2nd Test ',
#  '3rd Test ',
#  '1st ODI ',
#  '2nd ODI ',
#  '3rd ODI ']

# %%
DATE=[]

# %%
date_tag=driver.find_elements_by_xpath("//div[@class='match-card-left match-schedule']")

# %%
date_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="35afceda-a79b-479d-9419-3ae2ca6634c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="64e396e3-f3db-495f-b075-4f88147c988e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="0aa1bd65-6a45-44c9-b427-304ba4c8670c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="daa716c7-cea2-4504-9d0c-a9ff3729ee87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="047448b6-1bad-41e0-a85b-7713f6289286")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="cf37b802-4844-4d27-acc7-bb9e3fe9afd0")>,
# ...

# %%
for i in date_tag:
    dtitle=i.text
    DATE.append(dtitle)

# %%
DATE
# Out:
# ['26 DEC 2021',
#  '27 DEC 2021',
#  '3 JAN 2022',
#  '11 JAN 2022',
#  '19 JAN 2022',
#  '21 JAN 2022',
#  '23 JAN 2022']

# %%
TIME=[]

# %%
time_tag=driver.find_elements_by_xpath("//div[@class='match-card-right match-schedule ']")

# %%
time_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="dc12661a-3dce-4c94-bf3c-9cb24a75a18b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="24b2cc9b-0ed2-4e54-b7bd-fbfb38c1a0b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="4c4f2629-2ae7-4182-ac1d-3e1eda3b3bcf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="2e30faf1-4662-4575-b886-9f2b7c3b4047")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="4eb0d532-fbbf-4ca2-bec5-83d91785828d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="20082f43-bcbf-462a-9f4a-249addc1e2ef")>,
# ...

# %%
for i in time_tag:
    timetitle=i.text
    TIME.append(timetitle)

# %%
TIME
# Out:
# ['1:30 PM IST',
#  '11:00 AM IST',
#  '1:30 PM IST',
#  '2:00 PM IST',
#  '2:00 PM IST',
#  '2:00 PM IST',
#  '2:00 PM IST']

# %%
Fixtures=pd.DataFrame({})

# %%
Fixtures['Title']=TITLE
Fixtures['Name']=NAME
Fixtures['Place']=PLACE
Fixtures['Date']=DATE
Fixtures['Time']=TIME

# %%
Fixtures
# Out:
#        Title                                            Name  \
# 0  1st Test   INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 1   9th ODI                          ACC U19 - ASIA CUP 2021
# 2  2nd Test   INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 3  3rd Test   INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 4   1st ODI    INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 5   2nd ODI    INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 6   3rd ODI    INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
#
#                                                Place         Date  \
# 0           SuperSport Park, Centurion\nMatch Centre  26 DEC 2021
# 1                                       ICC Academy   27 DEC 2021
# 2   The Wanderers Stadium, Johannesburg\nMatch Ce...   3 JAN 2022
# 3                  Newlands, Cape Town\nMatch Centre  11 JAN 2022
# 4                   Boland Park, Paarl\nMatch Centre  19 JAN 2022
# 5                   Boland Park, Paarl\nMatch Centre  21 JAN 2022
# ...

# %% [markdown]
# # Q)3)SELENIUM EXCEPTION HANDLING

# %%
driver.get("https://www.guru99.com/")

# %%
search_tab=driver.find_element_by_id("gsc-i-id1")

# %%
search_tab.send_keys("Selenium Exception Handling")

# %%
search_button=driver.find_element_by_xpath("//button[@class='gsc-search-button gsc-search-button-v2']")

# %%
search_button.click()

# %%
NAME=[]

# %%
name_tag=driver.find_elements_by_xpath("//div[@class='gs-title']/a[1]")

# %%
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="0d3743ca-7419-4a68-b028-4cb823911e00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="c8e43631-e370-47a8-bc5c-26a75b226a2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="463dfc8f-18a9-47ef-917f-433c9046af55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="af40f19f-5861-4e0b-abf9-c6288e22703f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="0c4fc694-14c1-474f-a78f-ba5f264ad97d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="2d7a75b1-59e1-4b3b-a8a9-e11fc53c8651")>,
# ...

# %%
for i in name_tag:
    ntitle=i.text
    NAME.append(ntitle)

# %%
NAME
# Out:
# ['Selenium Exception Handling (Common Exceptions List)',
#  'How to Handle SSL Certificate in Selenium WebDriver',
#  'Implicit, Explicit and Fluent Wait in Selenium WebDriver',
#  'How to Take Screenshot in Selenium WebDriver',
#  'Find Element and FindElements by XPath in Selenium WebDriver',
#  'JavaScriptExecutor in Selenium WebDriver with Example',
#  'Database Testing using Selenium: Step by Step Guide',
#  'How to Handle AJAX Call in Selenium Webdriver',
#  'Log4j with Selenium Tutorial: Download, Install, Use & Example',
#  'Using SoapUI with Selenium for Web Service Testing',
#  '']

# %%
DISCRIPTION=[]

# %%
disc_tag=driver.find_elements_by_xpath("//div[@class='gs-bidi-start-align gs-snippet']")

# %%
disc_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="741d70c6-43db-4ea5-a85c-f0dc15638f9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="224fad0a-33c6-41fc-9213-f44bb65ea259")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="a6189937-f9cb-4805-b4cb-128f6ba559ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="52dbfaa2-12f9-4941-9cd2-f4d656fd4241")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="2a83fb14-5095-4e39-8e84-77c5a5398924")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="ef8e41cf-43e5-40b8-9f7b-5aa5fdd9501b")>,
# ...

# %%
for i in disc_tag:
    dtitle=i.text
    DISCRIPTION.append(dtitle)

# %%
DISCRIPTION
# Out:
# ['10-Nov-2021 ... In this tutorial, you will learn: What is an Exceptions? Exceptions in Selenium Web driver; Handling Selenium Exceptions; Methods for displaying ...',
#  '8 days ago ... For handling SSL certificate error in Firefox, we need to use desired capabilities of Selenium Webdriver and follow the following steps.',
#  '07-Oct-2021 ... Selenium Web Driver has borrowed the idea of implicit waits from Watir. In the below example we have declared an implicit wait with the time ...',
#  '07-Oct-2021 ... Selenium can automatically take screenshots during execution. ... testGuru99TakeScreenShot() throws Exception{ WebDriver driver ; System.',
#  '11-Dec-2021 ... Example: WebElement loginLink = driver.findElement(By.linkText("Login"));. FindElements command syntax: FindElements in Selenium command takes ...',
#  '07-Oct-2021 ... JavaScriptExecutor provides two methods “executescript” & “executeAsyncScript” to run javascript on the selected window or current page. Execute ...',
# ...

# %%
Selenium=pd.DataFrame({})

# %%
Selenium['Title']=NAME
Selenium['Discription']=DISCRIPTION

# %%
Selenium
# Out:
#                                                 Title  \
# 0   Selenium Exception Handling (Common Exceptions...
# 1   How to Handle SSL Certificate in Selenium WebD...
# 2   Implicit, Explicit and Fluent Wait in Selenium...
# 3        How to Take Screenshot in Selenium WebDriver
# 4   Find Element and FindElements by XPath in Sele...
# 5   JavaScriptExecutor in Selenium WebDriver with ...
# 6   Database Testing using Selenium: Step by Step ...
# 7       How to Handle AJAX Call in Selenium Webdriver
# 8   Log4j with Selenium Tutorial: Download, Instal...
# 9   Using SoapUI with Selenium for Web Service Tes...
# 10
#
#                                           Discription
# 0   10-Nov-2021 ... In this tutorial, you will lea...
# 1   8 days ago ... For handling SSL certificate er...
# 2   07-Oct-2021 ... Selenium Web Driver has borrow...
# 3   07-Oct-2021 ... Selenium can automatically tak...
# 4   11-Dec-2021 ... Example: WebElement loginLink ...
# ...

# %% [markdown]
# # 5)Trending repositories from githhub

# %%
driver.get("https://github.com/")

# %%
Explore_tag=_tag=driver.find_elements_by_xpath("//a[@class='HeaderMenu-details details-overlay details-reset width-full']")

# %%
for i in Explore_tag:
    if i.text=='Explore':
        i.click()
        break

# %%
trend_tab=driver.find_elements_by_xpath("//div[@class='lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2']")
trend_tab.click()

# %%
TITLE=[]

# %%
Title_tab=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a[1]")

# %%
Title_tab
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="43c0a1a1-c51e-4853-8491-090f75b9e8ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="a92e70b2-2ae3-4d9f-9b80-70bca0e1e93a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="de983332-4779-4888-a33c-7c8057787877")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="8d783685-4627-40c6-9c9b-d4c53a5e6074")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="b67e687d-94bf-4bef-8c85-5fe329e5bcde")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="d73ba2d9-ee24-458c-8ed5-0fec831d00eb")>,
# ...

# %%
for i in Title_tab:
    ttitle=i.text
    TITLE.append(ttitle[0:20])

# %%
TITLE
# Out:
# ['cisagov / log4j-scan',
#  'open-mmlab / mmrazor',
#  'sxyu / svox2',
#  'mpcabete / bombcrypt',
#  'Anuken / Mindustry',
#  'marktext / marktext',
#  'h3r2tic / cornell-mc',
#  'd2forum / 16th',
#  'mehdihadeli / awesom',
#  'Tencent / tdesign-re',
#  'fanux / sealos',
#  'Tencent / tdesign',
#  'wailsapp / wails',
#  'ssssssss-team / spid',
#  '30-seconds / 30-seco',
#  'mtdvio / every-progr',
#  'wader / fq',
#  'easychen / pushdeer',
#  'airbnb / javascript',
#  'TeamNewPipe / NewPip',
#  'prisma / prisma',
#  'Tencent / tdesign-vu',
#  'bozbez / win-capture',
#  'Courseplay / coursep',
#  'freeCodeCamp / Learn']

# %%
DISCRIPTION=[]

# %%
dis_tab=driver.find_elements_by_xpath("//p[@class='col-9 color-fg-muted my-1 pr-4']")

# %%
dis_tab
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="9a41feba-34df-45e6-8df9-daba58d33933")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="3f281b9d-6328-4b3d-ba5c-d4ffda72bdcf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="27d5c3cc-c875-4ffb-955e-dc7ed4377fcc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="54e392cb-1dae-4945-85bc-be7ada41adf8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="45d56377-3a6e-4f9d-a991-a68bd430f12e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="388b2eed-cd31-492f-a287-fc9ec0be8369")>,
# ...

# %%
for i in dis_tab:
    dtitle=i.text
    DISCRIPTION.append(dtitle[0:20])

# %%
DISCRIPTION
# Out:
# ['log4j-scanner is a p',
#  'OpenMMLab Model Comp',
#  'Plenoxels: Radiance ',
#  'This is a python bot',
#  'The automation tower',
#  '📝A simple and elegan',
#  "🕹 A quick'n'dirty ga",
#  '第十六届D2前端技术论坛「精心」',
#  'A curated list of aw',
#  'A React UI component',
#  '一条命令离线安装高可用kubernete',
#  'Enterprise Design Sy',
#  'Create desktop apps ',
#  '新一代爬虫平台，以图形化方式定义爬虫流程',
#  'Short JavaScript cod',
#  'A collection of (mos',
#  'jq for binary format',
#  '开放源码的无App推送服务，🚧 WIP',
#  'JavaScript Style Gui',
#  'A libre lightweight ',
#  'Next-generation ORM ',
#  'A Vue3.x UI componen',
#  'An OBS plugin that a',
#  'Courseplay for Farmi',
#  'A visual novel video']

# %%
LANGUAGE=[]

# %%
lan_tab=driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']/span[2]")

# %%
lan_tab
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="9797e264-6577-48a8-9027-97e96306c9c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="a658da43-a612-4dc4-a356-d77cbe3d633a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="d094d2df-1e7f-4548-8d45-0b5fcfc1f436")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="4103ee9d-95b5-475e-a52d-c7ee24fc8b62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="b45ef799-bb10-45cc-83e1-4a7adf469abd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a387f5a9412e90ef779b52649c41c6c4", element="d9646797-72f4-495c-9e5d-cf54ed4e9926")>,
# ...

# %%
for i in lan_tab:
    ltitle=i.text
    LANGUAGE.append(ltitle[0:20])

# %%
LANGUAGE
# Out:
# ['Java',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'JavaScript',
#  'Rust',
#  'Go',
#  'TypeScript',
#  'Go',
#  'Go',
#  'Java',
#  'JavaScript',
#  'Go',
#  'PHP',
#  'JavaScript',
#  'Java',
#  'TypeScript',
#  'TypeScript',
#  'C++',
#  'Lua',
#  "Ren'Py"]

# %%
Githhub=pd.DataFrame({})

# %%
Githhub['Title']=TITLE
Githhub['Discription']=DISCRIPTION
Githhub['Language']=LANGUAGE

# %%
Githhub
# Out:
#                    Title           Discription    Language
# 0   cisagov / log4j-scan  log4j-scanner is a p        Java
# 1   open-mmlab / mmrazor  OpenMMLab Model Comp      Python
# 2           sxyu / svox2  Plenoxels: Radiance       Python
# 3   mpcabete / bombcrypt  This is a python bot      Python
# 4     Anuken / Mindustry  The automation tower        Java
# 5    marktext / marktext  📝A simple and elegan  JavaScript
# 6   h3r2tic / cornell-mc  🕹 A quick'n'dirty ga        Rust
# 7         d2forum / 16th      第十六届D2前端技术论坛「精心」          Go
# 8   mehdihadeli / awesom  A curated list of aw  TypeScript
# 9   Tencent / tdesign-re  A React UI component          Go
# 10        fanux / sealos  一条命令离线安装高可用kubernete          Go
# 11     Tencent / tdesign  Enterprise Design Sy        Java
# 12      wailsapp / wails  Create desktop apps   JavaScript
# 13  ssssssss-team / spid  新一代爬虫平台，以图形化方式定义爬虫流程          Go
# 14  30-seconds / 30-seco  Short JavaScript cod         PHP
# ...

# %% [markdown]
# # Q)6)top 100 songs billiboard

# %%
driver.get("https://www.billboard.com/")

# %%
chart_tag=driver.find_element_by_xpath("//li[@class='o-nav__list-item lrv-u-align-items-center lrv-u-flex']/a")

# %%
chart_tag.click()

# %%
hot_tag=driver.find_elements_by_xpath("//li[@class='o-nav__list-item']/a[1]")
hot_tag.click()

# %%
SONG_NAME=[]

# %%
name=driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']")

# %%
name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="9e87fb56-8d3a-4dde-87fc-f752aefbe559")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="4d7dea6b-89e9-4436-8395-7927185dcd45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="924b03db-42ec-43bd-9db2-b48189455fde")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="7b0aa52a-683f-4ad6-a555-a944f63e5f25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="a95710fd-fd2c-427b-afee-a74265495472")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="8305e599-0c9a-49f3-b888-a94b67574a55")>,
# ...

# %%
for i in name:
    ntitle=i.text
    SONG_NAME.append(ntitle[0:100])

# %%
SONG_NAME
# Out:
# ['All I Want For Christmas Is You\nMariah Carey\n2\n1\n49',
#  "Rockin' Around The Christmas Tree\nBrenda Lee\n3\n2\n43",
#  'Easy On Me\nAdele\n1\n1\n10',
#  'Jingle Bell Rock\nBobby Helms\n6\n3\n40',
#  'A Holly Jolly Christmas\nBurl Ives\n5\n4\n24',
#  'Stay\nThe Kid LAROI & Justin Bieber\n4\n1\n23',
#  "It's The Most Wonderful Time Of The Year\nAndy Williams\n10\n5\n25",
#  'Heat Waves\nGlass Animals\n9\n7\n48',
#  'Last Christmas\nWham!\n13\n9\n23',
#  'Industry Baby\nLil Nas X & Jack Harlow\n8\n1\n21',
#  'Feliz Navidad\nJose Feliciano\n14\n6\n18',
#  'Shivers\nEd Sheeran\n11\n5\n14',
#  'Sleigh Ride\nThe Ronettes\n17\n13\n14',
#  'Need To Know\nDoja Cat\n12\n8\n27',
#  'The Christmas Song (Merry Christmas To You)\nNat King Cole\n20\n11\n30',
#  'abcdefu\nGAYLE\n15\n15\n4',
#  'Let It Snow, Let It Snow, Let It Snow\nDean Martin\n18\n8\n17',
#  'Underneath The Tree\nKelly Clarkson\n24\n12\n13',
# ...

# %%
ARTIST=[]

# %%
artist=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']")

# %%
artist
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="382a1187-9ac7-44b9-a753-a05420d47a78")>]

# %%
for i in artist:
    atitle=i.text
    ARTIST.append(atitle)

# %%
ARTIST
# Out:
# ['Mariah Carey']

# %%
artist2=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")

# %%
artist2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="0b005a62-d12b-4d65-929f-40be7906f814")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="61289209-7daa-4ff2-8b2b-3b073022a1a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="20f64581-d519-4c33-a057-d5c24fb8992a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="bfd659d5-3e58-4b70-8c9b-f23269012d7b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="4c02922a-765e-4000-83bc-81c073e98277")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="3ca48672-df0e-40f2-8e90-be358e89bca1")>,
# ...

# %%
for i in artist2:
    ttitle=i.text
    ARTIST.append(ttitle)

# %%
ARTIST
# Out:
# ['Mariah Carey',
#  'Brenda Lee',
#  'Adele',
#  'Bobby Helms',
#  'Burl Ives',
#  'The Kid LAROI & Justin Bieber',
#  'Andy Williams',
#  'Glass Animals',
#  'Wham!',
#  'Lil Nas X & Jack Harlow',
#  'Jose Feliciano',
#  'Ed Sheeran',
#  'The Ronettes',
#  'Doja Cat',
#  'Nat King Cole',
#  'GAYLE',
#  'Dean Martin',
#  'Kelly Clarkson',
#  'Perry Como And The Fontane Sisters With Mitchell Ayres And His Orchestra',
#  'Kodak Black',
#  'Gene Autry',
#  'Andy Williams',
#  'Elton John & Dua Lipa',
#  'Ariana Grande',
#  'Darlene Love',
#  'Ed Sheeran',
#  'Bing Crosby',
#  'Perry Como',
#  'Juice WRLD & SUGA',
#  'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'SZA',
#  'Chuck Berry',
#  'Olivia Rodrigo',
#  'Juice WRLD',
#  'Walker Hayes',
#  'Michael Buble',
#  'Justin Bieber',
#  'Post Malone & The Weeknd',
#  'Wizkid Featuring Justin Bieber & Tems',
#  'Doja Cat & The Weeknd',
#  'Paul McCartney',
#  'Doja Cat Featuring SZA',
#  'Billie Eilish',
#  'Thurl Ravenscroft',
# ...

# %%
LASTRANK=[]

# %%
lrank=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max']")

# %%
lrank
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="e615921c-4cc6-4499-ab86-e469e08466b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="5208a210-5563-4374-b88c-b4340a233d3d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="346e0190-1101-4b74-9e63-b94359d4e5ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="475d27d5-85bd-47fb-a84b-f4fe16a5fb0e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="baf6beb6-3a27-4213-b78d-3f39ef9b5653")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="af53bbb5-74a7-4eea-9903-ebfed799c9d8")>,
# ...

# %%
for i in lrank:
    rtitle=i.text
    LASTRANK.append(rtitle[0:100])

# %%
PEAK_POS=[]

# %%
peak=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-flex-grow-1']/span")

# %%
peak
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="82e1ac94-8eaa-4c34-91cb-cfaef19b6ba3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="7079b586-6aad-4673-9085-e46e112d891e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="1d29a386-9596-431e-9e58-11e8575bbe2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="8f1b20d4-3674-418b-a80e-f598554146aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="97c9b84e-9621-4da7-80e4-ef13db2a7a70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b5906e4e86bd7263080e562ea7170b6d", element="55207e49-8fb7-47d9-9709-7756ce0e84ad")>,
# ...

# %%
for i in peak:
    ptitle=i.text
    PEAK_POS.append(ptitle[0:100])

# %%
PEAK_POS
# Out:
# ['1',
#  '2',
#  '1',
#  '3',
#  '4',
#  '1',
#  '5',
#  '7',
#  '9',
#  '1',
#  '6',
#  '5',
#  '13',
#  '8',
#  '11',
#  '15',
#  '8',
#  '12',
#  '12',
#  '20',
#  '16',
#  '18',
#  '11',
#  '17',
#  '17',
#  '2',
#  '12',
#  '22',
#  '29',
#  '5',
#  '7',
#  '10',
#  '1',
#  '34',
#  '3',
#  '20',
#  '32',
#  '6',
#  '9',
#  '11',
#  '28',
#  '3',
#  '11',
#  '32',
#  '10',
#  '1',
#  '31',
#  '4',
#  '11',
#  '50',
#  '5',
#  '30',
#  '29',
#  '20',
#  '49',
#  '56',
#  '30',
#  '21',
#  '1',
#  '2',
#  '39',
#  '17',
#  '63',
#  '64',
#  '61',
#  '66',
#  '32',
#  '68',
#  '58',
#  '28',
#  '69',
#  '32',
#  '53',
#  '1',
#  '75',
#  '76',
#  '59',
#  '62',
#  '77',
#  '80',
#  '74',
#  '82',
#  '83',
#  '57',
#  '85',
#  '86',
#  '87',
#  '65',
#  '45',
#  '68',
#  '80',
#  '48',
#  '18',
#  '87',
#  '76',
#  '13',
#  '49',
#  '98',
#  '89',
#  '20']

# %%
WEAK=[]

# %%
weak=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1']/span")

# %%
for i in weak:
    wtitle=i.text
    WEAK.append(wtitle[0:100])

# %%
WEAK
# Out:
# ['2',
#  '49',
#  '3',
#  '43',
#  '1',
#  '10',
#  '6',
#  '40',
#  '5',
#  '24',
#  '4',
#  '23',
#  '10',
#  '25',
#  '9',
#  '48',
#  '13',
#  '23',
#  '8',
#  '21',
#  '14',
#  '18',
#  '11',
#  '14',
#  '17',
#  '14',
#  '12',
#  '27',
#  '20',
#  '30',
#  '15',
#  '4',
#  '18',
#  '17',
#  '24',
#  '13',
#  '21',
#  '10',
#  '23',
#  '6',
#  '27',
#  '15',
#  '26',
#  '11',
#  '19',
#  '15',
#  '30',
#  '11',
#  '25',
#  '10',
#  '16',
#  '25',
#  '28',
#  '23',
#  '37',
#  '10',
#  '-',
#  '1',
#  '22',
#  '6',
#  '7',
#  '2',
#  '34',
#  '12',
#  '29',
#  '31',
#  '-',
#  '1',
#  '31',
#  '26',
#  '32',
#  '8',
#  '40',
#  '12',
#  '38',
#  '6',
#  '35',
#  '24',
#  '33',
#  '25',
#  '-',
#  '5',
#  '36',
#  '36',
#  '46',
#  '20',
#  '-',
#  '3',
#  '50',
#  '13',
#  '39',
#  '15',
#  '48',
#  '13',
#  '44',
#  '15',
#  '-',
#  '11',
#  '-',
#  '1',
#  '47',
#  '4',
#  '45',
#  '18',
#  '51',
#  '9',
#  '-',
#  '4',
#  '49',
#  '2',
#  '-',
#  '1',
#  '56',
#  '19',
# ...

# %%
SONGS=pd.DataFrame({})

# %%
SONGS['Name']=NAME[0:50]
SONGS['Artist']=ARTIST[0:50]
SONGS['Peak']=PEAK_POS[0:50]
SONGS['Weaks']=WEAK[0:50]

# %%
SONGS
# Out:
#     Name                                             Artist Last_rank Peak  \
# 0    NaN                                       Mariah Carey              1
# 1    NaN                                         Brenda Lee              2
# 2    NaN                                              Adele              1
# 3    NaN                                        Bobby Helms              3
# 4    NaN                                          Burl Ives              4
# 5    NaN                      The Kid LAROI & Justin Bieber              1
# 6    NaN                                      Andy Williams              5
# 7    NaN                                      Glass Animals              7
# 8    NaN                                              Wham!              9
# 9    NaN                            Lil Nas X & Jack Harlow              1
# 10   NaN                                     Jose Feliciano              6
# ...
